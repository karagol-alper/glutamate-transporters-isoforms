# %%
# !pip install Biopython
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 17.4 MB/s eta 0:00:00
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
from Bio import Phylo
from io import StringIO

def plot_tree(treedata, output_file):
    handle = StringIO(treedata)  # parse the newick string
    tree = Phylo.read(handle, "newick")
    matplotlib.rc('font', size=6)
    # set the size of the figure
    fig = plt.figure(figsize=(10, 10), dpi=200)
    # alternatively
    # fig.set_size_inches(10, 20)
    axes = fig.add_subplot(1, 1, 1)
    Phylo.draw(tree, axes=axes)
    plt.savefig(output_file, dpi=200)

    return

plot_tree("((tr|M0R2V7|M0R2V7_HUMAN:1.9290554304064411,((sp|P43005|EAA3_HUMAN:1.4209027169149862,tr|H0Y7R2|H0Y7R2_HUMAN:0.0):5.679864239838956,((((tr|A0A2R8YHI4|A0A2R8YHI4_HUMAN:0.0,(sp|P43004|EAA2_HUMAN:1.4806512505899003,tr|A0A2R8Y4N0|A0A2R8Y4N0_HUMAN:0.0):1.4065695296523526):0.7150160677768032,tr|A0A2R8Y642|A0A2R8Y642_HUMAN:2.766579024247737):0.71290824612053,tr|H0YEB1|H0YEB1_HUMAN:0.0):1.5014648437500018,(((tr|A0A087X0U3|A0A087X0U3_HUMAN:2.3968209704406016,tr|A0A7P0T9Z4|A0A7P0T9Z4_HUMAN:0.0):0.2668913464643201,(sp|P43003|EAA1_HUMAN:1.8393546921154271,tr|A0A7P0Z4R4|A0A7P0Z4R4_HUMAN:0.0):2.2024338069099128):2.087679435870399,((((tr|A0A7P0T807|A0A7P0T807_HUMAN:1.0913535276073607,tr|A0A7P0T9A4|A0A7P0T9A4_HUMAN:1.4853335889570563):0.3515282646801021,tr|A0A7P0TAW2|A0A7P0TAW2_HUMAN:1.6116619193689705):1.087279524539881,tr|A0A7P0T800|A0A7P0T800_HUMAN:1.581432131901837):0.4413583205521463,((tr|M0QY32|M0QY32_HUMAN:0.0,(sp|P48664|EAA4_HUMAN:0.09269138436916569,tr|M0R106|M0R106_HUMAN:0.0):0.8604294478527614):2.097033167177913,(((tr|E7EUS7|E7EUS7_HUMAN:0.0,(tr|A0A7P0T8Q1|A0A7P0T8Q1_HUMAN:0.45489403234801556,((tr|A0A7P0T8P5|A0A7P0T8P5_HUMAN:0.4866682397357238,tr|E7EUV6|E7EUV6_HUMAN:0.0):0.04984662576687093,tr|A0A7P0TB50|A0A7P0TB50_HUMAN:0.3182515337423315):0.03590351366424738):0.18424079754601608):0.7635693592365373,tr|A0A7P0T8T4|A0A7P0T8T4_HUMAN:1.5753876959781867):0.3423660371932489,(tr|F1T0D2|F1T0D2_HUMAN:0.0,(tr|F1T0D3|F1T0D3_HUMAN:1.87947341513292,(tr|F1T0D4|F1T0D4_HUMAN:1.2411042944785193,sp|O00341|EAA5_HUMAN:1.8877300613496875):1.6481339468302698):0.8444529652351764):1.3318095763036817):0.13120686349693012):0.5039302147239271):0.0):0.16204646759969288):0.0):0.8845529380751538):3.0232023461464728,(tr|A0A2R8Y4D1|A0A2R8Y4D1_HUMAN:0.0,tr|C9J9N5|C9J9N5_HUMAN:0.06346519991538013):3.0232023461464728);", "/content/NJPID2.png")
